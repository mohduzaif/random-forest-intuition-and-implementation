# %% [markdown]
# ### Import Libaraies.

# %%
import pandas as pd 
import numpy as np 

from sklearn.datasets import make_regression

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR 
from sklearn.ensemble import BaggingRegressor

from sklearn.metrics import r2_score, mean_squared_error

# %%
# load the dataset.

# %%
# Generate a synthetic dataset
X, y = make_regression(n_samples=10000, n_features=1, noise=10.0, random_state=42)

# %%
# train test split. 
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
print(X_train.shape) 
print(X_test.shape) 
print(y_train.shape) 
print(y_test.shape)
# Out:
# (8000, 1)
# (2000, 1)
# (8000,)
# (2000,)

# %% [markdown]
# ### Build the separete Regressor.

# %%
# training.

# %%
dt_reg = DecisionTreeRegressor()
dt_reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# testing. 
y_pred = dt_reg.predict(X_test)

# %%
y_pred
# Out:
# array([ 38.35639071,  36.79465695,  -1.86605978, ...,  10.73753623,
#        -43.17961491,   9.24822711], shape=(2000,))

# %%
## aaccuracy_score. 
print('R2 Score : ', r2_score(y_test, y_pred))
# Out:
# R2 Score :  0.8163962884490039

# %%
## mean_squared_error. 
print('Mean Square Error : ', mean_squared_error(y_test, y_pred))
# Out:
# Mean Square Error :  199.5168530657983

# %% [markdown]
# ### Bagging with Decision Tree.

# %%
# training od model.

# %%
bag_reg = BaggingRegressor(
        DecisionTreeRegressor(),
        n_estimators=10, 
        max_samples=0.25, 
        bootstrap=True, 
        verbose=1
)

bag_reg.fit(X_train, y_train)
# Out:
# BaggingRegressor(estimator=DecisionTreeRegressor(), max_samples=0.25, verbose=1)

# %%
# testing. 
y_pred = bag_reg.predict(X_test)

# %%
## aaccuracy_score. 
print('R2 Score : ', r2_score(y_test, y_pred))
# Out:
# R2 Score :  0.8861983800271397

# %%
## mean_squared_error. 
print('Mean Square Error : ', mean_squared_error(y_test, y_pred))
# Out:
# Mean Square Error :  123.66493519641378

# %% [markdown]
# ### Bagging with SVM.

# %%
bag_svr = BaggingRegressor(
        SVR(),
        n_estimators=10, 
        max_samples=0.25, 
        bootstrap=True, 
        verbose=1
)

bag_svr.fit(X_train, y_train)
# Out:
# BaggingRegressor(estimator=SVR(), max_samples=0.25, verbose=1)

# %%
# testing. 
y_pred = bag_svr.predict(X_test)

# %%
## aaccuracy_score. 
print('R2 Score : ', r2_score(y_test, y_pred))
# Out:
# R2 Score :  0.8625356969805651

# %%
## mean_squared_error. 
print('Mean Square Error : ', mean_squared_error(y_test, y_pred))
# Out:
# Mean Square Error :  149.37848976818339

# %% [markdown]
# ### Pasting.

# %% [markdown]
# `NOTE : ` We can do the pasting as well it a one of the type of Bagging, we can implement it just make bootstrap=false.
